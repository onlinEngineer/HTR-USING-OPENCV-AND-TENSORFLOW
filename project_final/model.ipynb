# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import pandas as pd

# %%
mnist = keras.datasets.mnist
(train_images_mnist,train_labels_mnist),(test_images_mnist,test_labels_mnist) = mnist.load_data()
# images are reshaped to be used by the flow method of a keras ImageGenerator
train_images_mnist = np.reshape(train_images_mnist,(train_images_mnist.shape[0],28,28,1))  
test_images_mnist = np.reshape(test_images_mnist,(test_images_mnist.shape[0],28,28,1))

train_images_mnist.shape
# Out:
# (60000, 28, 28, 1)

# %%
AZ_data = pd.read_csv('A_Z Handwritten Data.csv',header = None)
# the first column contains label values, while the remaining are the flattened array of 28 x 28 image pixels
AZ_labels = AZ_data.values[:,0]
AZ_images = AZ_data.values[:,1:]
# images are reshaped to be used by the flow method of a keras ImageGenerator
AZ_images = np.reshape(AZ_images,(AZ_images.shape[0],28,28,1))

# %%
# join datasets
# split AZ data in train and test
from sklearn.model_selection import train_test_split

test_size = float(len(test_labels_mnist))/len(train_labels_mnist)
print(f'test set size: {test_size}')
train_images_AZ, test_images_AZ, train_labels_AZ, test_labels_AZ = train_test_split(AZ_images,AZ_labels, test_size=test_size)
#shift mnist labels 
train_labels_mnist = train_labels_mnist + max(AZ_labels)+1
test_labels_mnist = test_labels_mnist + max(AZ_labels)+1

# concatenate datasets
train_images = np.concatenate((train_images_AZ,train_images_mnist),axis=0)
train_labels = np.concatenate((train_labels_AZ,train_labels_mnist))
test_images = np.concatenate((test_images_AZ,test_images_mnist),axis=0)
test_labels = np.concatenate((test_labels_AZ,test_labels_mnist))

print('Data ready')
# Out:
# test set size: 0.16666666666666666
# Data ready

# %%
import tensorflow as tf
from tensorflow.keras.optimizers import RMSprop,Adam
model = tf.keras.models.Sequential([
    # Note the input shape is the desired size of the image 150x150 with 3 bytes color
    tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(28, 28, 1)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2), 
    # Flatten the results to feed into a DNN
    tf.keras.layers.Flatten(), 
    # 512 neuron hidden layer
    tf.keras.layers.Dense(512, activation='relu'), 

    tf.keras.layers.Dense(len(np.unique(train_labels)), activation='softmax')  
])


model.compile(optimizer=Adam(learning_rate=1e-4),
              loss='sparse_categorical_crossentropy',
              metrics = ['accuracy'])

model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_10 (Conv2D)          (None, 26, 26, 64)        640
#
#  max_pooling2d_9 (MaxPooling  (None, 13, 13, 64)       0
#  2D)
#
#  conv2d_11 (Conv2D)          (None, 11, 11, 64)        36928
#
#  max_pooling2d_10 (MaxPoolin  (None, 5, 5, 64)         0
#  g2D)
#
#  flatten_4 (Flatten)         (None, 1600)              0
#
#  dense_8 (Dense)             (None, 512)               819712
#
#  dense_9 (Dense)             (None, 36)                18468
#
# =================================================================
# Total params: 875,748
# Trainable params: 875,748
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(
      rescale=1./255,
      rotation_range=15,
      width_shift_range=0.1,
      height_shift_range=0.1,
      shear_range=0.1,
      zoom_range=0.2,
      horizontal_flip=False,
      fill_mode='nearest')

test_datagen = ImageDataGenerator(rescale=1./255)

# %%
# Flow training images in batches using generator
train_generator = train_datagen.flow(train_images, train_labels, batch_size=128, shuffle=True)
validation_generator = test_datagen.flow(test_images, test_labels, batch_size=128, shuffle=True)

# %%
history = model.fit(
      train_generator,
      steps_per_epoch=500,  
      epochs=100,
      validation_data=validation_generator,
      validation_steps=50,  
      verbose=1)
model.save("model_v2")
# Out:
# Epoch 1/100
# 500/500 [==============================] - 19s 37ms/step - loss: 1.8098 - accuracy: 0.5153 - val_loss: 0.5269 - val_accuracy: 0.8516
# Epoch 2/100
# 500/500 [==============================] - 18s 36ms/step - loss: 0.8637 - accuracy: 0.7592 - val_loss: 0.3430 - val_accuracy: 0.9119
# Epoch 3/100
# 500/500 [==============================] - 18s 37ms/step - loss: 0.6344 - accuracy: 0.8199 - val_loss: 0.2868 - val_accuracy: 0.9239
# Epoch 4/100
# 500/500 [==============================] - 18s 37ms/step - loss: 0.5449 - accuracy: 0.8446 - val_loss: 0.2747 - val_accuracy: 0.9242
# Epoch 5/100
# 500/500 [==============================] - 18s 36ms/step - loss: 0.4841 - accuracy: 0.8615 - val_loss: 0.2447 - val_accuracy: 0.9327
# Epoch 6/100
# 500/500 [==============================] - 18s 37ms/step - loss: 0.4460 - accuracy: 0.8724 - val_loss: 0.2198 - val_accuracy: 0.9402
# Epoch 7/100
# 500/500 [==============================] - 18s 37ms/step - loss: 0.4116 - accuracy: 0.8799 - val_loss: 0.2072 - val_accuracy: 0.9402
# Epoch 8/100
# 500/500 [==============================] - 18s 37ms/step - loss: 0.3870 - accuracy: 0.8880 - val_loss: 0.2158 - val_accuracy: 0.9348
# Epoch 9/100
# 500/500 [==============================] - 18s 36ms/step - loss: 0.3693 - accuracy: 0.8930 - val_loss: 0.2008 - val_accuracy: 0.9425
# Epoch 10/100
# 500/500 [==============================] - 18s 37ms/step - loss: 0.3488 - accuracy: 0.8989 - val_loss: 0.1818 - val_accuracy: 0.9456
# Epoch 11/100
# 500/500 [==============================] - 18s 37ms/step - loss: 0.3408 - accuracy: 0.9007 - val_loss: 0.1893 - val_accuracy: 0.9425
# Epoch 12/100
# 500/500 [==============================] - 18s 37ms/step - loss: 0.3243 - accuracy: 0.9045 - val_loss: 0.1759 - val_accuracy: 0.9508
# Epoch 13/100
# 500/500 [==============================] - 18s 37ms/step - loss: 0.3146 - accuracy: 0.9081 - val_loss: 0.1879 - val_accuracy: 0.9483
# Epoch 14/100
# 500/500 [==============================] - 18s 37ms/step - loss: 0.2970 - accuracy: 0.9116 - val_loss: 0.2012 - val_accuracy: 0.9359
# Epoch 15/100
# 500/500 [==============================] - 18s 37ms/step - loss: 0.2898 - accuracy: 0.9126 - val_loss: 0.1599 - val_accuracy: 0.9519
# Epoch 16/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.2870 - accuracy: 0.9152 - val_loss: 0.1730 - val_accuracy: 0.9469
# Epoch 17/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.2749 - accuracy: 0.9183 - val_loss: 0.1647 - val_accuracy: 0.9516
# Epoch 18/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.2724 - accuracy: 0.9182 - val_loss: 0.1638 - val_accuracy: 0.9492
# Epoch 19/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.2619 - accuracy: 0.9220 - val_loss: 0.1534 - val_accuracy: 0.9534
# Epoch 20/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.2538 - accuracy: 0.9244 - val_loss: 0.1599 - val_accuracy: 0.9514
# Epoch 21/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.2525 - accuracy: 0.9248 - val_loss: 0.1505 - val_accuracy: 0.9545
# Epoch 22/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.2478 - accuracy: 0.9258 - val_loss: 0.1640 - val_accuracy: 0.9519
# Epoch 23/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.2455 - accuracy: 0.9255 - val_loss: 0.1662 - val_accuracy: 0.9508
# Epoch 24/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.2432 - accuracy: 0.9278 - val_loss: 0.1662 - val_accuracy: 0.9464
# Epoch 25/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.2301 - accuracy: 0.9308 - val_loss: 0.1588 - val_accuracy: 0.9505
# Epoch 26/100
# 500/500 [==============================] - 17s 34ms/step - loss: 0.2291 - accuracy: 0.9310 - val_loss: 0.1510 - val_accuracy: 0.9563
# Epoch 27/100
# 500/500 [==============================] - 17s 35ms/step - loss: 0.2319 - accuracy: 0.9307 - val_loss: 0.1453 - val_accuracy: 0.9550
# Epoch 28/100
# 500/500 [==============================] - 17s 35ms/step - loss: 0.2283 - accuracy: 0.9311 - val_loss: 0.1379 - val_accuracy: 0.9580
# Epoch 29/100
# 500/500 [==============================] - 17s 35ms/step - loss: 0.2210 - accuracy: 0.9327 - val_loss: 0.1468 - val_accuracy: 0.9591
# Epoch 30/100
# 500/500 [==============================] - 17s 35ms/step - loss: 0.2156 - accuracy: 0.9358 - val_loss: 0.1333 - val_accuracy: 0.9611
# Epoch 31/100
# 500/500 [==============================] - 17s 35ms/step - loss: 0.2146 - accuracy: 0.9352 - val_loss: 0.1382 - val_accuracy: 0.9566
# Epoch 32/100
# 500/500 [==============================] - 18s 35ms/step - loss: 0.2122 - accuracy: 0.9365 - val_loss: 0.1403 - val_accuracy: 0.9584
# Epoch 33/100
# 500/500 [==============================] - 17s 35ms/step - loss: 0.2068 - accuracy: 0.9373 - val_loss: 0.1575 - val_accuracy: 0.9530
# Epoch 34/100
# 500/500 [==============================] - 17s 35ms/step - loss: 0.2029 - accuracy: 0.9380 - val_loss: 0.1114 - val_accuracy: 0.9658
# Epoch 35/100
# 500/500 [==============================] - 19s 37ms/step - loss: 0.2011 - accuracy: 0.9384 - val_loss: 0.1343 - val_accuracy: 0.9586
# Epoch 36/100
# 500/500 [==============================] - 18s 36ms/step - loss: 0.1974 - accuracy: 0.9400 - val_loss: 0.1398 - val_accuracy: 0.9592
# Epoch 37/100
# 500/500 [==============================] - 18s 37ms/step - loss: 0.1982 - accuracy: 0.9398 - val_loss: 0.1353 - val_accuracy: 0.9564
# Epoch 38/100
# 500/500 [==============================] - 18s 36ms/step - loss: 0.1997 - accuracy: 0.9401 - val_loss: 0.1390 - val_accuracy: 0.9570
# Epoch 39/100
# 500/500 [==============================] - 18s 36ms/step - loss: 0.1916 - accuracy: 0.9408 - val_loss: 0.1371 - val_accuracy: 0.9581
# Epoch 40/100
# 500/500 [==============================] - 18s 37ms/step - loss: 0.1901 - accuracy: 0.9412 - val_loss: 0.1516 - val_accuracy: 0.9472
# Epoch 41/100
# 500/500 [==============================] - 18s 36ms/step - loss: 0.1938 - accuracy: 0.9413 - val_loss: 0.1390 - val_accuracy: 0.9572
# Epoch 42/100
# 500/500 [==============================] - 18s 36ms/step - loss: 0.1867 - accuracy: 0.9429 - val_loss: 0.1270 - val_accuracy: 0.9594
# Epoch 43/100
# 500/500 [==============================] - 18s 36ms/step - loss: 0.1841 - accuracy: 0.9437 - val_loss: 0.1237 - val_accuracy: 0.9650
# Epoch 44/100
# 500/500 [==============================] - 18s 35ms/step - loss: 0.1857 - accuracy: 0.9416 - val_loss: 0.1327 - val_accuracy: 0.9594
# Epoch 45/100
# 500/500 [==============================] - 18s 35ms/step - loss: 0.1810 - accuracy: 0.9459 - val_loss: 0.1352 - val_accuracy: 0.9605
# Epoch 46/100
# 500/500 [==============================] - 18s 36ms/step - loss: 0.1786 - accuracy: 0.9451 - val_loss: 0.1441 - val_accuracy: 0.9569
# Epoch 47/100
# 500/500 [==============================] - 18s 36ms/step - loss: 0.1784 - accuracy: 0.9452 - val_loss: 0.1282 - val_accuracy: 0.9641
# Epoch 48/100
# 500/500 [==============================] - 18s 36ms/step - loss: 0.1850 - accuracy: 0.9429 - val_loss: 0.1297 - val_accuracy: 0.9628
# Epoch 49/100
# 500/500 [==============================] - 18s 36ms/step - loss: 0.1774 - accuracy: 0.9451 - val_loss: 0.1322 - val_accuracy: 0.9611
# Epoch 50/100
# 500/500 [==============================] - 18s 36ms/step - loss: 0.1771 - accuracy: 0.9452 - val_loss: 0.1275 - val_accuracy: 0.9539
# Epoch 51/100
# 500/500 [==============================] - 18s 36ms/step - loss: 0.1745 - accuracy: 0.9466 - val_loss: 0.1093 - val_accuracy: 0.9642
# Epoch 52/100
# 500/500 [==============================] - 18s 36ms/step - loss: 0.1770 - accuracy: 0.9463 - val_loss: 0.1257 - val_accuracy: 0.9648
# Epoch 53/100
# 500/500 [==============================] - 18s 36ms/step - loss: 0.1756 - accuracy: 0.9460 - val_loss: 0.1414 - val_accuracy: 0.9569
# Epoch 54/100
# 500/500 [==============================] - 18s 36ms/step - loss: 0.1733 - accuracy: 0.9463 - val_loss: 0.1226 - val_accuracy: 0.9623
# Epoch 55/100
# 500/500 [==============================] - 18s 36ms/step - loss: 0.1715 - accuracy: 0.9475 - val_loss: 0.1293 - val_accuracy: 0.9603
# Epoch 56/100
# 500/500 [==============================] - 18s 36ms/step - loss: 0.1717 - accuracy: 0.9473 - val_loss: 0.1424 - val_accuracy: 0.9533
# Epoch 57/100
# 500/500 [==============================] - 18s 36ms/step - loss: 0.1701 - accuracy: 0.9467 - val_loss: 0.1319 - val_accuracy: 0.9613
# Epoch 58/100
# 500/500 [==============================] - 18s 36ms/step - loss: 0.1657 - accuracy: 0.9487 - val_loss: 0.1219 - val_accuracy: 0.9630
# Epoch 59/100
# 500/500 [==============================] - 18s 36ms/step - loss: 0.1681 - accuracy: 0.9474 - val_loss: 0.1168 - val_accuracy: 0.9647
# Epoch 60/100
# 500/500 [==============================] - 18s 35ms/step - loss: 0.1687 - accuracy: 0.9478 - val_loss: 0.1071 - val_accuracy: 0.9670
# Epoch 61/100
# 500/500 [==============================] - 18s 35ms/step - loss: 0.1626 - accuracy: 0.9498 - val_loss: 0.1229 - val_accuracy: 0.9627
# Epoch 62/100
# 500/500 [==============================] - 18s 36ms/step - loss: 0.1592 - accuracy: 0.9507 - val_loss: 0.1323 - val_accuracy: 0.9558
# Epoch 63/100
# 500/500 [==============================] - 18s 36ms/step - loss: 0.1645 - accuracy: 0.9485 - val_loss: 0.1305 - val_accuracy: 0.9567
# Epoch 64/100
# 500/500 [==============================] - 18s 36ms/step - loss: 0.1623 - accuracy: 0.9495 - val_loss: 0.1223 - val_accuracy: 0.9620
# Epoch 65/100
# 500/500 [==============================] - 18s 36ms/step - loss: 0.1644 - accuracy: 0.9485 - val_loss: 0.1390 - val_accuracy: 0.9581
# Epoch 66/100
# 500/500 [==============================] - 18s 36ms/step - loss: 0.1591 - accuracy: 0.9507 - val_loss: 0.1326 - val_accuracy: 0.9605
# Epoch 67/100
# 500/500 [==============================] - 18s 35ms/step - loss: 0.1559 - accuracy: 0.9510 - val_loss: 0.1281 - val_accuracy: 0.9592
# Epoch 68/100
# 500/500 [==============================] - 18s 36ms/step - loss: 0.1573 - accuracy: 0.9527 - val_loss: 0.1096 - val_accuracy: 0.9655
# Epoch 69/100
# 500/500 [==============================] - 18s 36ms/step - loss: 0.1583 - accuracy: 0.9514 - val_loss: 0.1276 - val_accuracy: 0.9589
# Epoch 70/100
# 500/500 [==============================] - 18s 35ms/step - loss: 0.1572 - accuracy: 0.9509 - val_loss: 0.1184 - val_accuracy: 0.9652
# Epoch 71/100
# 500/500 [==============================] - 18s 37ms/step - loss: 0.1522 - accuracy: 0.9529 - val_loss: 0.1173 - val_accuracy: 0.9644
# Epoch 72/100
# 500/500 [==============================] - 18s 36ms/step - loss: 0.1586 - accuracy: 0.9508 - val_loss: 0.1280 - val_accuracy: 0.9636
# Epoch 73/100
# 500/500 [==============================] - 18s 36ms/step - loss: 0.1543 - accuracy: 0.9520 - val_loss: 0.1248 - val_accuracy: 0.9630
# Epoch 74/100
# 500/500 [==============================] - 18s 36ms/step - loss: 0.1524 - accuracy: 0.9530 - val_loss: 0.1091 - val_accuracy: 0.9641
# Epoch 75/100
# 500/500 [==============================] - 18s 36ms/step - loss: 0.1531 - accuracy: 0.9525 - val_loss: 0.1156 - val_accuracy: 0.9633
# Epoch 76/100
# 500/500 [==============================] - 18s 35ms/step - loss: 0.1492 - accuracy: 0.9531 - val_loss: 0.1336 - val_accuracy: 0.9588
# Epoch 77/100
# 500/500 [==============================] - 18s 37ms/step - loss: 0.1513 - accuracy: 0.9526 - val_loss: 0.1249 - val_accuracy: 0.9597
# Epoch 78/100
# 500/500 [==============================] - 18s 37ms/step - loss: 0.1522 - accuracy: 0.9535 - val_loss: 0.1165 - val_accuracy: 0.9617
# Epoch 79/100
# 500/500 [==============================] - 18s 36ms/step - loss: 0.1524 - accuracy: 0.9522 - val_loss: 0.1435 - val_accuracy: 0.9572
# Epoch 80/100
# 500/500 [==============================] - 18s 36ms/step - loss: 0.1520 - accuracy: 0.9523 - val_loss: 0.1265 - val_accuracy: 0.9594
# Epoch 81/100
# 500/500 [==============================] - 18s 36ms/step - loss: 0.1445 - accuracy: 0.9547 - val_loss: 0.1035 - val_accuracy: 0.9678
# Epoch 82/100
# 500/500 [==============================] - 18s 36ms/step - loss: 0.1470 - accuracy: 0.9541 - val_loss: 0.1205 - val_accuracy: 0.9625
# Epoch 83/100
# 500/500 [==============================] - 18s 36ms/step - loss: 0.1436 - accuracy: 0.9544 - val_loss: 0.1116 - val_accuracy: 0.9655
# Epoch 84/100
# 500/500 [==============================] - 18s 36ms/step - loss: 0.1447 - accuracy: 0.9538 - val_loss: 0.1048 - val_accuracy: 0.9652
# Epoch 85/100
# 500/500 [==============================] - 18s 36ms/step - loss: 0.1443 - accuracy: 0.9545 - val_loss: 0.1184 - val_accuracy: 0.9634
# Epoch 86/100
# 500/500 [==============================] - 18s 36ms/step - loss: 0.1434 - accuracy: 0.9558 - val_loss: 0.1258 - val_accuracy: 0.9623
# Epoch 87/100
# 500/500 [==============================] - 18s 36ms/step - loss: 0.1436 - accuracy: 0.9543 - val_loss: 0.1186 - val_accuracy: 0.9641
# Epoch 88/100
# 500/500 [==============================] - 18s 36ms/step - loss: 0.1427 - accuracy: 0.9554 - val_loss: 0.1194 - val_accuracy: 0.9627
# Epoch 89/100
# 500/500 [==============================] - 18s 36ms/step - loss: 0.1450 - accuracy: 0.9548 - val_loss: 0.1027 - val_accuracy: 0.9661
# Epoch 90/100
# 500/500 [==============================] - 18s 36ms/step - loss: 0.1410 - accuracy: 0.9566 - val_loss: 0.1222 - val_accuracy: 0.9652
# Epoch 91/100
# 500/500 [==============================] - 18s 36ms/step - loss: 0.1424 - accuracy: 0.9559 - val_loss: 0.1035 - val_accuracy: 0.9650
# Epoch 92/100
# 500/500 [==============================] - 18s 37ms/step - loss: 0.1408 - accuracy: 0.9557 - val_loss: 0.1239 - val_accuracy: 0.9628
# Epoch 93/100
# 500/500 [==============================] - 18s 37ms/step - loss: 0.1402 - accuracy: 0.9560 - val_loss: 0.0970 - val_accuracy: 0.9688
# Epoch 94/100
# 500/500 [==============================] - 18s 36ms/step - loss: 0.1421 - accuracy: 0.9550 - val_loss: 0.1190 - val_accuracy: 0.9613
# Epoch 95/100
# 500/500 [==============================] - 18s 36ms/step - loss: 0.1433 - accuracy: 0.9554 - val_loss: 0.1369 - val_accuracy: 0.9566
# Epoch 96/100
# 500/500 [==============================] - 18s 36ms/step - loss: 0.1428 - accuracy: 0.9547 - val_loss: 0.1233 - val_accuracy: 0.9603
# Epoch 97/100
# 500/500 [==============================] - 18s 36ms/step - loss: 0.1397 - accuracy: 0.9565 - val_loss: 0.1030 - val_accuracy: 0.9689
# Epoch 98/100
# 500/500 [==============================] - 18s 36ms/step - loss: 0.1377 - accuracy: 0.9562 - val_loss: 0.1221 - val_accuracy: 0.9627
# Epoch 99/100
# 500/500 [==============================] - 18s 36ms/step - loss: 0.1433 - accuracy: 0.9550 - val_loss: 0.1176 - val_accuracy: 0.9641
# Epoch 100/100
# 500/500 [==============================] - 18s 36ms/step - loss: 0.1381 - accuracy: 0.9566 - val_loss: 0.1123 - val_accuracy: 0.9652
# INFO:tensorflow:Assets written to: model_v2\assets

# %%
import matplotlib.pyplot as plt
    

    # Print accuracy and loss function
fig = plt.figure(figsize=(12, 6))
ax = fig.add_subplot(1, 2, 1)
ax.plot(history.history["loss"],'r-x', label="Train Loss")
ax.plot(history.history["val_loss"],'b-x', label="Validation Loss")
ax.legend()
ax.set_title('cross_entropy loss')
ax.grid(True)


ax = fig.add_subplot(1, 2, 2)
ax.plot(history.history["accuracy"],'r-x', label="Train Accuracy")
ax.plot(history.history["val_accuracy"],'b-x', label="Validation Accuracy")
ax.legend()
ax.set_title('accuracy')
ax.grid(True)

# %%
from tensorflow.keras.models import load_model
import tensorflow as tf
import cv2
import matplotlib.pyplot as plt

import imutils
from imutils.contours import sort_contours

# %%
# loads the model with the keras load_model function
model_path = "model_v2"
print("Loading NN model...")
model = load_model(model_path)
print("Done")
# Out:
# Loading NN model...
# Done

# %%
image_path = 'hand.png'
image = cv2.imread(image_path)

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cropped = gray[5:,:]
blurred = cv2.GaussianBlur(cropped, (5, 5), 0)


# %matplotlib inline
from matplotlib import cm
fig = plt.figure(figsize=(16,4))
ax = plt.subplot(1,4,1)
ax.imshow(image)
ax.set_title('original image')

ax = plt.subplot(1,4,2)
ax.imshow(gray,cmap=cm.binary_r)
ax.set_axis_off()
ax.set_title('grayscale image')

ax = plt.subplot(1,4,3)
ax.imshow(cropped,cmap=cm.binary_r)
ax.set_axis_off()
ax.set_title('cropped image')

ax = plt.subplot(1,4,4)
ax.imshow(blurred,cmap=cm.binary_r)
ax.set_axis_off()
ax.set_title('blurred image')
#plt.imshow(gray,cmap=cm.binary_r)
# Out:
# Text(0.5, 1.0, 'blurred image')

# %%
# perform edge detection, find contours in the edge map, and sort the
# resulting contours from left-to-right
edged = cv2.Canny(blurred, 30, 250) #low_threshold, high_threshold
cnts = cv2.findContours(edged.copy(), cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
cnts = imutils.grab_contours(cnts)
cnts = sort_contours(cnts, method="left-to-right")[0]

figure = plt.figure(figsize=(7,7))
plt.axis('off')
plt.imshow(edged,cmap=cm.binary_r)

# %%
import numpy as np
chars = []
mylist_w=[]
mylist_x=[]
# loop over the contours
for c in cnts:
	# compute the bounding box of the contour and isolate ROI
  (x, y, w, h) = cv2.boundingRect(c)
  roi = cropped[y:y + h, x:x + w]
  mylist_x.append(x)
  mylist_w.append(x+w)
  
  #binarize image, finds threshold with OTSU method
  thresh = cv2.threshold(roi, 0, 255,cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)[1]
  
  # resize largest dimension to input size
  (tH, tW) = thresh.shape
  if tW > tH:
    thresh = imutils.resize(thresh, width=28)
  # otherwise, resize along the height
  else:
    thresh = imutils.resize(thresh, height=28)

  # find how much is needed to pad
  (tH, tW) = thresh.shape
  dX = int(max(0, 28 - tW) / 2.0)
  dY = int(max(0, 28 - tH) / 2.0)
  # pad the image and force 28 x 28 dimensions
  padded = cv2.copyMakeBorder(thresh, top=dY, bottom=dY,
    left=dX, right=dX, borderType=cv2.BORDER_CONSTANT,
    value=(0, 0, 0))
  padded = cv2.resize(padded, (28, 28))
  # reshape and rescale padded image for the model
  padded = padded.astype("float32") / 255.0
  padded = np.expand_dims(padded, axis=-1)
  # append image and bounding box data in char list
  chars.append((padded, (x, y, w, h)))

# %%
# plot isolated characters
n_cols = 10
n_rows = np.floor(len(chars)/ n_cols)+1
fig = plt.figure(figsize=(1.5*n_cols,1.5*n_rows))
for i,char in enumerate(chars):
  ax = plt.subplot(int(n_rows),int(n_cols),i+1)
  ax.imshow(char[0][:,:,0],cmap=cm.binary,aspect='auto')
  #plt.axis('off')
plt.tight_layout()

# %%
boxes = [b[1] for b in chars]
chars = np.array([c[0] for c in chars], dtype="float32")
# OCR the characters using our handwriting recognition model
preds = model.predict(chars)




# define the list of label names
labelNames = "ABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789"

# %%
image = cv2.imread(image_path)
cropped = image[5:,:]
euc=[]


for (pred, (x, y, w, h)) in zip(preds, boxes):
	# find the index of the label with the largest corresponding
	# probability, then extract the probability and label
  i = np.argmax(pred)
  prob = pred[i]
  label = labelNames[i]
  euc.append(label)

  # draw the prediction on the image and it's probability
  label_text = f"{label},{prob * 100:.1f}%"
  cv2.rectangle(cropped, (x, y), (x + w, y + h), (0,255 , 0), 2)
 


  cv2.putText(cropped, label_text, (x - 10, y - 10),cv2.FONT_HERSHEY_SIMPLEX,0.5, (0,0,0), 1)
# show the image


mylist_x.append(0)
print("Upper Left Corner of Rectangles:",mylist_x)
print("Upper Right Corner of Rectangles:",mylist_w)                 

differences=[]

for i in range(len(mylist_w)):
  first=mylist_x[i+1]-mylist_w[i]
  differences.append(first)
print("Consecutive Differences Between Each Corners:",differences)


characters=[]
for i,j in zip(range(len(differences)),range(len(euc))):
  
  characters.append(euc[j])
  if differences[i]>30:
    characters.append(" ")


print("Characters:",characters)

output="".join(characters)  


output_split=output.split()

print("Raw Sentence:",output)

from spellchecker import SpellChecker
 
spell = SpellChecker()
 


for i in range(len(output_split)):
    # Get the one `most likely` answer
    correct=spell.correction(output_split[i])
    output_split[i]=correct.upper()


output_split=" ".join(output_split)
    
print("Corrected Sentence:",output_split)


import translators as ts
trans=ts.google(output_split,to_language='tr')

print("Translated Sentence:",trans)
  

plt.figure(figsize=(15,10))

plt.imshow(cropped)



blank_image_path="blank.JPG"
blank_image=cv2.imread(blank_image_path)


# cv2.putText(blank_image, trans, (150,130),cv2.FONT_HERSHEY_SIMPLEX,2, (0,0,0), 2)

# plt.figure(figsize=(15,10))
# plt.imshow(blank_image)

# Importing the PIL library
from PIL import Image
from PIL import ImageDraw
from PIL import ImageFont
 
# Open an Image
img = Image.open('blank.jpg')
# Call draw Method to add 2D graphics in an image
I1 = ImageDraw.Draw(img)
 
# Custom font style and font size
myFont = ImageFont.truetype('OpenSans-Regular.ttf', 65)
 
# Add Text to an image
I1.text((50, 50), trans, font=myFont, fill =(255, 0, 0))
img.save("translated.jpg")
from IPython.display import Image 
pil_img = Image(filename='translated.jpg')
# Out:
# Upper Left Corner of Rectangles: [30, 195, 238, 361, 440, 498, 562, 614, 670, 744, 842, 994, 1051, 0]
# Upper Right Corner of Rectangles: [112, 231, 308, 428, 492, 546, 605, 668, 732, 815, 893, 1046, 1099]
# Consecutive Differences Between Each Corners: [83, 7, 53, 12, 6, 16, 9, 2, 12, 27, 101, 5, -1099]
# Characters: ['I', ' ', 'A', 'M', ' ', 'S', 'T', 'U', 'D', 'Y', 'I', 'N', 'G', ' ', 'D', 'L']
# Raw Sentence: I AM STUDYING DL
# Corrected Sentence: I AM STUDYING DO
# Translated Sentence: Ben okuyorum

# %%
display(pil_img)
